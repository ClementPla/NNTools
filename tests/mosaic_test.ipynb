# %%
# %load_ext autoreload
# %autoreload 2
 
import nntools.dataset as D

# %%
img_root = "/home/clement/Documents/phd/DR/MessidorAnnotation/img/images/"
diagnosis = "/home/clement/Documents/phd/DR/MessidorAnnotation/diagnostic.xls"

dataset = D.ClassificationDataset(img_root, shape=(512, 512), label_filepath=diagnosis, 
                                  gt_column="retinopathy", file_column="name")

# %%
dataset.plot(0)
# Out:
# /home/clement/Documents/phd/NNTools/src/nntools/utils/plotting.py:151: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
img_root = "/home/clement/Documents/phd/DR/MessidorAnnotation/img/images/"
label = "/home/clement/Documents/phd/DR/MessidorAnnotation/labelId/"
dataset = D.SegmentationDataset(img_root, mask_root=label, shape=(1024, 1024))

# %%
dataset.plot(0)

# %%
dataset = D.ImageDataset(img_root)

# %%
dataset.plot(0)
# Out:
# /home/clement/Documents/phd/NNTools/src/nntools/utils/plotting.py:151: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
dataset = D.MultiImageDataset({'test': img_root, 'test2': img_root}, shape=(512, 512))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 dataset = D.MultiImageDataset({'test': img_root, 'test2': img_root}, shape=(512, 512))
#
# File <attrs generated init nntools.dataset.image_dataset.MultiImageDataset>:31, in __init__(self, img_root, shape, keep_size_ratio, extract_image_id_function, recursive_loading, use_cache, flag, return_indices, cmap_name, multiplicative_size_factor, return_tag, id, tag, interpolation_flag, auto_pad, auto_resize, precache_composer, filling_strategy)
#      29     __attr_validator_auto_pad(self, __attr_auto_pad, self.auto_pad)
#      30     __attr_validator_auto_resize(self, __attr_auto_resize, self.auto_resize)
# ---> 31 self.__attrs_post_init__()
#
# File ~/Documents/phd/NNTools/src/nntools/dataset/abstract_image_dataset.py:104, in AbstractImageDataset.__attrs_post_init__(self)
#     102 self.cache_filled = False
#     103 self._is_first_process = False
# --> 104 self.list_files(self.recursive_loading)
#
# File ~/Documents/phd/NNTools/src/nntools/dataset/image_dataset.py:30, in MultiImageDataset.list_files(self, recursive)
#      28     for root_label, paths in img_root.items():
#      29         for path in paths:
# ---> 30             self.img_filepath[root_label].extend(glob.glob(path + prefix + extension, recursive=recursive))
#      32 imgs_ids = {}
#      33 for k, filepaths in self.img_filepath.items():
#
# File ~/miniconda3/lib/python3.10/glob.py:24, in glob(pathname, root_dir, dir_fd, recursive)
#      13 def glob(pathname, *, root_dir=None, dir_fd=None, recursive=False):
#      14     """Return a list of paths matching a pathname pattern.
#      15
#      16     The pattern may contain simple shell-style wildcards a la
#    (...)
#      22     zero or more directories and subdirectories.
#      23     """
# ---> 24     return list(iglob(pathname, root_dir=root_dir, dir_fd=dir_fd, recursive=recursive))
#
# File ~/miniconda3/lib/python3.10/glob.py:86, in _iglob(pathname, root_dir, dir_fd, recursive, dironly)
#      84     glob_in_dir = _glob0
#      85 for dirname in dirs:
# ---> 86     for name in glob_in_dir(_join(root_dir, dirname), basename, dir_fd, dironly):
#      87         yield os.path.join(dirname, name)
#
# File ~/miniconda3/lib/python3.10/glob.py:94, in _glob1(dirname, pattern, dir_fd, dironly)
#      93 def _glob1(dirname, pattern, dir_fd, dironly):
# ---> 94     names = _listdir(dirname, dir_fd, dironly)
#      95     if not _ishidden(pattern):
#      96         names = (x for x in names if not _ishidden(x))
#
# File ~/miniconda3/lib/python3.10/glob.py:164, in _listdir(dirname, dir_fd, dironly)
#     162 def _listdir(dirname, dir_fd, dironly):
#     163     with contextlib.closing(_iterdir(dirname, dir_fd, dironly)) as it:
# --> 164         return list(it)
#
# File ~/miniconda3/lib/python3.10/glob.py:149, in _iterdir(dirname, dir_fd, dironly)
#     147 for entry in it:
#     148     try:
# --> 149         if not dironly or entry.is_dir():
#     150             if fsencode is not None:
#     151                 yield fsencode(entry.name)
#
# KeyboardInterrupt:

# %%
# Out:
# {'image': array([], dtype=float64)}
